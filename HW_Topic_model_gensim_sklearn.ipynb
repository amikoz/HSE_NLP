# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim
import string
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

morph = MorphAnalyzer()

# %% [markdown]
# ## Данные

# %%
stops = set(stopwords.words('russian')) | {'gt',}
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return norm_words

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %%
# f = open('habr_texts.vw', 'w')

# for i, text in enumerate(habr_texts):
#     c = Counter(text)
#     doc = 'doc_'+ str(i) + ' '
#     vw_text = ' '.join([x+':'+str(c[x]) for x in c])
    
#     f.write(doc + vw_text  + '\n')
# f.close()

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [tokenize(remove_tags(text.lower())) for text in texts]
# Out:
# CPU times: user 3.04 s, sys: 452 ms, total: 3.49 s
# Wall time: 3.66 s

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [normalize(tokenize(text.lower())) for text in texts]
# Out:
# CPU times: user 13min 44s, sys: 5.21 s, total: 13min 50s
# Wall time: 14min 2s

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)
# Out:
# CPU times: user 10.7 s, sys: 592 ms, total: 11.2 s
# Wall time: 11.4 s

# %%
# для нграммов
# ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
# p = gensim.models.phrases.Phraser(ph)
# ngrammed_texts = p[texts]

# %% [markdown]
# ### Тематическое моделирование в gensim

# %% [markdown]
# Для моделей нужно сделать словарь.

# %%
def lda_gensim(texts, no_above=0.3, ngrams=True, tfidf=False, passes=10, eta='auto', iterations=10, num_topics=100):
    
    if ngrams:
        ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
        p = gensim.models.phrases.Phraser(ph)
        ngrammed_texts = p[texts]
        
    dictionary = gensim.corpora.Dictionary(texts)
    dictionary.filter_extremes(no_above=no_above)
    dictionary.compactify()
    
    corpus = [dictionary.doc2bow(text) for text in ngrammed_texts]
    
    if tfidf:
        tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary)
        corpus = tfidf[corpus]
        
    lda_model = gensim.models.LdaModel(corpus=corpus, 
                                       id2word=dictionary,
                                       num_topics=num_topics,
                                       random_state=40,
                                       passes=passes,
                                       eta=eta, 
                                       iterations=iterations)
    return lda_model

# %%
# %%time
lda_model= lda_gensim(texts)
# Out:
# CPU times: user 1min 17s, sys: 1.69 s, total: 1min 19s
# Wall time: 1min 17s

# %%
lda_model.print_topics()
# Out:
# [(96,
#   '0.017*"машина" + 0.012*"vpn" + 0.012*"to" + 0.011*"this" + 0.011*"выбор" + 0.009*"пост" + 0.009*"or" + 0.009*"т.е" + 0.009*"email" + 0.008*"вывод"'),
#  (69,
#   '0.018*"понять" + 0.017*"исследование" + 0.010*"тест" + 0.009*"почему" + 0.009*"продукт" + 0.009*"понимать" + 0.008*"какой-то" + 0.007*"тестирование" + 0.007*"цель" + 0.007*"этап"'),
#  (2,
#   '0.054*"сопротивляться" + 0.053*"чен" + 0.043*"всё-равно" + 0.021*"издательство" + 0.019*"вынуждать" + 0.019*"переименование" + 0.013*"продюсер" + 0.013*"хищник" + 0.010*"численность" + 0.010*"quest"'),
#  (90,
#   '0.030*"apple" + 0.026*"процессор" + 0.020*"железо" + 0.019*"память" + 0.018*"видеокарта" + 0.017*"чип" + 0.015*"производительность" + 0.015*"gpu" + 0.013*"ноутбук" + 0.012*"nvidia"'),
#  (13,
#   '0.023*"архитектура" + 0.014*"логика" + 0.013*"uber" + 0.013*"представление" + 0.012*"поток" + 0.011*"бизнес-логика" + 0.010*"состояние" + 0.010*"presenter" + 0.009*"содержимый" + 0.008*"элемент"'),
#  (29,
#   '0.032*"звук" + 0.028*"устройство" + 0.025*"усилитель" + 0.016*"сигнал" + 0.014*"инструмент" + 0.012*"фильтр" + 0.010*"w" + 0.009*"характеристика" + 0.008*"сегодня" + 0.008*"with"'),
#  (26,
#   '0.025*"точка" + 0.014*"объект" + 0.012*"карта" + 0.011*"земля" + 0.011*"координата" + 0.010*"расстояние" + 0.009*"спутник" + 0.009*"размер" + 0.009*"звезда" + 0.008*"планета"'),
#  (30,
#   '0.022*"контейнер" + 0.015*"файл" + 0.014*"сервер" + 0.013*"установка" + 0.012*"конфигурация" + 0.012*"сборка" + 0.011*"установить" + 0.011*"настроить" + 0.011*"настройка" + 0.009*"ключ"'),
#  (45,
#   '0.026*"height" + 0.019*"t2" + 0.019*"≤" + 0.018*"gnu/linux" + 0.017*"width" + 0.017*"player" + 0.012*"room" + 0.012*"t1" + 0.011*"pass" + 0.010*"skip"'),
#  (9,
#   '0.029*"сеть" + 0.023*"доступ" + 0.015*"защита" + 0.014*"безопасность" + 0.012*"организация" + 0.012*"точка" + 0.009*"управление" + 0.009*"технология" + 0.008*"корпоративный" + 0.008*"подключение"'),
#  (32,
#   '0.017*"to" + 0.016*"0" + 0.012*"status" + 0.012*"master" + 0.011*"version" + 0.011*"нода" + 0.011*"пакет" + 0.009*"on" + 0.008*"set" + 0.008*"load"'),
#  (98,
#   '0.066*"обучение" + 0.060*"слой" + 0.056*"модель" + 0.055*"сеть" + 0.043*"признак" + 0.040*"нейрон" + 0.031*"набор" + 0.019*"обучать" + 0.016*"входной" + 0.015*"вектор"'),
#  (53,
#   '0.037*"батарея" + 0.034*"аккумулятор" + 0.028*"квт*ч" + 0.022*"ёмкость" + 0.020*"ячейка" + 0.017*"tesla" + 0.016*"производство" + 0.014*"100" + 0.011*"ассемблер" + 0.011*"напряжение"'),
#  (73,
#   '0.045*"велосипед" + 0.037*"lt;meta" + 0.032*"a5" + 0.028*"employee" + 0.020*"a3" + 0.019*"ipfs" + 0.019*"angle" + 0.018*"фонарик" + 0.015*"домофон" + 0.014*"uno"'),
#  (46,
#   '0.059*"текст" + 0.046*"язык" + 0.039*"перевод" + 0.019*"символ" + 0.018*"дизайн" + 0.015*"название" + 0.012*"локализация" + 0.012*"кнопка" + 0.012*"предложение" + 0.010*"подпись"'),
#  (43,
#   '0.011*"fixedupdate" + 0.010*"gameobject" + 0.010*"спутниковый" + 0.008*"vector3" + 0.008*"00:00" + 0.008*"глонасс" + 0.006*"0f" + 0.005*"ericsson" + 0.003*"фокус" + 0.002*"0.0f"'),
#  (1,
#   '0.026*"рынок" + 0.012*"сервер" + 0.012*"стоимость" + 0.012*"хостинг" + 0.010*"цена" + 0.009*"месяц" + 0.009*"появиться" + 0.008*"платформа" + 0.008*"собственный" + 0.007*"бизнес"'),
#  (24,
#   '0.075*"сервер" + 0.025*"сервис" + 0.021*"запрос" + 0.018*"клиент" + 0.011*"ответ" + 0.010*"сертификат" + 0.009*"настройка" + 0.008*"поддержка" + 0.008*"http" + 0.008*"протокол"'),
#  (86,
#   '0.014*"память" + 0.014*"обновление" + 0.013*"размер" + 0.013*"инструкция" + 0.010*"модель" + 0.009*"ядро" + 0.008*"процессор" + 0.008*"realm" + 0.008*"кэш" + 0.008*"происходить"'),
#  (72,
#   '0.072*"модуль" + 0.019*"спецификация" + 0.019*"актор" + 0.015*"загрузка" + 0.014*"сообщение" + 0.014*"браузер" + 0.014*"systemjs" + 0.012*"загрузчик" + 0.010*"транзакция" + 0.010*"api"')]

# %% [markdown]
# ###### Постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;

# %%
topics = [10, 25, 50, 100]

# %%
for i in topics:
    lda_model = lda_gensim(texts, passes=20, num_topics=i)
    print('%s:\n%s\n' % ('LDA %s' % i, lda_model.print_topics(10)))
# Out:
# LDA 10:
# [(0, '0.047*"игра" + 0.019*"игрок" + 0.008*"играть" + 0.006*"понять" + 0.006*"игровой" + 0.006*"исследование" + 0.005*"машина" + 0.005*"тест" + 0.005*"карта" + 0.004*"понимать"'), (1, '0.009*"устройство" + 0.007*"сеть" + 0.006*"сайт" + 0.005*"цена" + 0.004*"смартфон" + 0.004*"интернет" + 0.003*"страна" + 0.003*"деньга" + 0.003*"товар" + 0.003*"производитель"'), (2, '0.014*"сервер" + 0.009*"сеть" + 0.009*"файл" + 0.006*"устройство" + 0.006*"настройка" + 0.005*"доступ" + 0.005*"пакет" + 0.004*"модуль" + 0.004*"запрос" + 0.004*"адрес"'), (3, '0.007*"элемент" + 0.006*"текст" + 0.006*"страница" + 0.006*"алгоритм" + 0.005*"язык" + 0.005*"изображение" + 0.005*"строка" + 0.004*"значение" + 0.004*"файл" + 0.004*"добавить"'), (4, '0.005*"мозг" + 0.005*"боль" + 0.004*"скорость" + 0.004*"учёный" + 0.004*"происходить" + 0.003*"технология" + 0.003*"исследование" + 0.003*"мир" + 0.003*"область" + 0.003*"сигнал"'), (5, '0.010*"модель" + 0.007*"звук" + 0.005*"инструмент" + 0.005*"компьютер" + 0.004*"её" + 0.004*"программист" + 0.004*"опыт" + 0.004*"история" + 0.004*"электроника" + 0.004*"устройство"'), (6, '0.013*"the" + 0.011*"to" + 0.010*"массив" + 0.009*"and" + 0.009*"0" + 0.009*"a" + 0.008*"for" + 0.006*"устройство" + 0.005*"of" + 0.005*"режим"'), (7, '0.011*"файл" + 0.008*"браузер" + 0.007*"сайт" + 0.006*"c" + 0.006*"вакансия" + 0.006*"язык" + 0.006*"бот" + 0.006*"доклад" + 0.006*"поиск" + 0.005*"канал"'), (8, '0.015*"return" + 0.012*"объект" + 0.010*"0" + 0.009*"if" + 0.008*"класс" + 0.008*"метод" + 0.008*"значение" + 0.007*"new" + 0.007*"файл" + 0.005*"свойство"'), (9, '0.009*"услуга" + 0.006*"клиент" + 0.006*"сотрудник" + 0.005*"продукт" + 0.005*"заказчик" + 0.005*"бизнес" + 0.004*"технология" + 0.004*"студент" + 0.004*"организация" + 0.004*"цель"')]
#
# LDA 25:
# [(11, '0.025*"запрос" + 0.014*"in" + 0.012*"условие" + 0.012*"p" + 0.011*"запись" + 0.010*"select" + 0.010*"модель" + 0.009*"from" + 0.009*"where" + 0.008*"c"'), (20, '0.017*"устройство" + 0.009*"материал" + 0.009*"производство" + 0.008*"звук" + 0.007*"технология" + 0.006*"печать" + 0.006*"инструмент" + 0.005*"модель" + 0.004*"батарея" + 0.004*"характеристика"'), (9, '0.013*"услуга" + 0.008*"бизнес" + 0.008*"сотрудник" + 0.008*"клиент" + 0.007*"заказчик" + 0.006*"организация" + 0.005*"управление" + 0.005*"документ" + 0.004*"крупный" + 0.004*"технология"'), (0, '0.022*"машина" + 0.011*"автомобиль" + 0.011*"карта" + 0.009*"часы" + 0.009*"режим" + 0.009*"прибор" + 0.008*"координата" + 0.006*"город" + 0.006*"точка" + 0.006*"зона"'), (21, '0.016*"студент" + 0.014*"курс" + 0.009*"программа" + 0.008*"программирование" + 0.007*"участник" + 0.006*"обучение" + 0.006*"программист" + 0.005*"лекция" + 0.005*"знание" + 0.005*"электроника"'), (18, '0.010*"устройство" + 0.008*"to" + 0.007*"сервер" + 0.007*"файл" + 0.007*"раздел" + 0.006*"0" + 0.006*"контейнер" + 0.006*"a" + 0.005*"скрипт" + 0.005*"for"'), (17, '0.017*"массив" + 0.014*"память" + 0.012*"ядро" + 0.011*"узел" + 0.011*"тест" + 0.010*"процессор" + 0.009*"сеть" + 0.009*"производительность" + 0.008*"операция" + 0.007*"режим"'), (22, '0.013*"мозг" + 0.011*"боль" + 0.010*"вакансия" + 0.008*"•" + 0.006*"область" + 0.006*"исследование" + 0.006*"жизнь" + 0.006*"происходить" + 0.006*"клетка" + 0.005*"лицо"'), (4, '0.009*"скорость" + 0.006*"температура" + 0.006*"робот" + 0.005*"энергия" + 0.005*"двигатель" + 0.005*"земля" + 0.004*"головка" + 0.004*"вселенная" + 0.003*"вода" + 0.003*"метр"'), (16, '0.009*"какой-то" + 0.009*"продукт" + 0.008*"доклад" + 0.006*"язык" + 0.006*"что-то" + 0.005*"перевод" + 0.005*"тестирование" + 0.005*"текст" + 0.005*"конференция" + 0.004*"рассказать"')]
#
# LDA 50:
# [(1, '0.039*"вакансия" + 0.015*"интернет" + 0.014*"страна" + 0.011*"технология" + 0.010*"опыт" + 0.009*"сеть" + 0.008*"выборка" + 0.007*"браузер" + 0.007*"навык" + 0.007*"область"'), (11, '0.019*"группа" + 0.017*"вселенная" + 0.015*"гипотеза" + 0.015*"хабра" + 0.012*"анализ" + 0.009*"галактика" + 0.009*"закон" + 0.008*"тысяча" + 0.008*"возраст" + 0.007*"звезда"'), (26, '0.021*"событие" + 0.018*"правило" + 0.015*"атака" + 0.012*"пароль" + 0.012*"инцидент" + 0.011*"сотрудник" + 0.009*"доступ" + 0.007*"клиент" + 0.007*"ключ" + 0.006*"настройка"'), (6, '0.032*"the" + 0.028*"and" + 0.026*"to" + 0.022*"for" + 0.018*"of" + 0.016*"a" + 0.013*"8" + 0.012*"with" + 0.012*"усилитель" + 0.010*"in"'), (17, '0.026*"массив" + 0.018*"узел" + 0.018*"сеть" + 0.015*"тест" + 0.011*"виртуальный" + 0.011*"репликация" + 0.010*"режим" + 0.010*"вычислительный" + 0.009*"задержка" + 0.009*"производительность"'), (49, '0.047*"игра" + 0.010*"её" + 0.008*"думать" + 0.008*"дизайнер" + 0.007*"история" + 0.007*"персонаж" + 0.007*"анимация" + 0.006*"что-то" + 0.005*"мир" + 0.005*"vr"'), (10, '0.036*"домен" + 0.027*"c" + 0.025*"сайт" + 0.025*"ссылка" + 0.011*"миграция" + 0.010*"cmake" + 0.008*"структура" + 0.008*"google" + 0.008*"обратный" + 0.007*"clion"'), (18, '0.016*"устройство" + 0.012*"раздел" + 0.011*"файл" + 0.010*"to" + 0.009*"контейнер" + 0.008*"база" + 0.007*"режим" + 0.007*"0" + 0.007*"консоль" + 0.006*"перезагрузка"'), (2, '0.033*"модуль" + 0.029*"пакет" + 0.010*"настройка" + 0.010*"сервер" + 0.010*"спецификация" + 0.009*"ip" + 0.009*"браузер" + 0.009*"порт" + 0.008*"конфигурация" + 0.008*"загрузка"'), (47, '0.018*"return" + 0.011*"in" + 0.011*"объект" + 0.010*"атрибут" + 0.010*"свойство" + 0.009*"null" + 0.008*"as" + 0.008*"new" + 0.007*"type" + 0.007*"поль"')]
#
# LDA 100:
# [(16, '0.039*"шорткат" + 0.028*"android" + 0.024*"действие" + 0.017*"добавить" + 0.015*"сообщение" + 0.014*"иконка" + 0.013*"→" + 0.010*"короткий" + 0.010*"подборка" + 0.010*"добавление"'), (15, '0.014*"аппарат" + 0.013*"страна" + 0.013*"поезд" + 0.013*"скорость" + 0.012*"станция" + 0.012*"спутник" + 0.012*"космический" + 0.011*"километр" + 0.011*"марс" + 0.011*"км/ч"'), (33, '0.085*"видео" + 0.040*"регистратор" + 0.032*"корея" + 0.028*"модель" + 0.024*"запись" + 0.022*"blackvue" + 0.019*"камера" + 0.017*"аппарат" + 0.016*"gps" + 0.015*"китайский"'), (60, '0.035*"firebase" + 0.030*"диск" + 0.022*"хранилище" + 0.018*"интеграция" + 0.015*"вм" + 0.015*"плагин" + 0.013*"хост" + 0.011*"объект" + 0.010*"хранение" + 0.010*"индекс"'), (37, '0.025*"устройство" + 0.015*"камера" + 0.013*"смартфон" + 0.011*"датчик" + 0.010*"экран" + 0.010*"дом" + 0.006*"управление" + 0.006*"цена" + 0.005*"дисплей" + 0.005*"производитель"'), (51, '0.025*"материал" + 0.018*"инструмент" + 0.018*"производство" + 0.015*"печать" + 0.015*"изделие" + 0.014*"деталь" + 0.010*"принтер" + 0.010*"прибор" + 0.010*"форма" + 0.009*"удобный"'), (86, '0.015*"обновление" + 0.013*"модель" + 0.012*"размер" + 0.011*"транзакция" + 0.010*"контакт" + 0.009*"инструкция" + 0.009*"realm" + 0.009*"ничто" + 0.008*"fun" + 0.008*"происходить"'), (96, '0.017*"машина" + 0.015*"vpn" + 0.012*"to" + 0.011*"т.е" + 0.011*"пост" + 0.011*"выбор" + 0.010*"email" + 0.010*"this" + 0.009*"тема" + 0.009*"сервер"'), (46, '0.056*"текст" + 0.050*"язык" + 0.040*"перевод" + 0.021*"символ" + 0.021*"дизайн" + 0.017*"название" + 0.013*"локализация" + 0.011*"подпись" + 0.011*"комментарий" + 0.010*"текстовый"'), (94, '0.019*"сотрудник" + 0.017*"документ" + 0.010*"предприятие" + 0.010*"срок" + 0.010*"контроль" + 0.009*"управление" + 0.009*"оборудование" + 0.009*"внедрение" + 0.009*"руководство" + 0.008*"план"')]

# %% [markdown]
# По моему мнению, три самые хорошие темы получились при num_topics = 100:
#
# 1.
# (33, '0.085*"видео" + 0.040*"регистратор" + 0.032*"корея" + 0.028*"модель" + 0.024*"запись" + 0.022*"blackvue" + 0.019*"камера" + 0.017*"аппарат" + 0.016*"gps" + 0.015*"китайский"')
#
# 2.
# (37, '0.025*"устройство" + 0.015*"камера" + 0.013*"смартфон" + 0.011*"датчик" + 0.010*"экран" + 0.010*"дом" + 0.006*"управление" + 0.006*"цена" + 0.005*"дисплей" + 0.005*"производитель"')
#
# 3.
# (94, '0.019*"сотрудник" + 0.017*"документ" + 0.010*"предприятие" + 0.010*"срок" + 0.010*"контроль" + 0.009*"управление" + 0.009*"оборудование" + 0.009*"внедрение" + 0.009*"руководство" + 0.008*"план"')

# %% [markdown]
# ####  tfidf

# %%
for i in topics:
    lda_model = lda_gensim(texts, passes=20, num_topics=i, tfidf=True)
    print('%s:\n%s\n' % ('LDA %s' % i, lda_model.print_topics(10)))
# Out:
# LDA 10:
# [(0, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"'), (1, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"yahoo" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа"'), (2, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"'), (3, '0.002*"файл" + 0.002*"безопасность" + 0.002*"сеть" + 0.001*"сервер" + 0.001*"браузер" + 0.001*"устройство" + 0.001*"windows" + 0.001*"сайт" + 0.001*"защита" + 0.001*"доступ"'), (4, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"'), (5, '0.002*"игра" + 0.001*"устройство" + 0.001*"сайт" + 0.001*"услуга" + 0.001*"продукт" + 0.001*"сеть" + 0.001*"технология" + 0.001*"игрок" + 0.001*"клиент" + 0.001*"сервис"'), (6, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"'), (7, '0.001*"файл" + 0.001*"сервер" + 0.001*"c" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа"'), (8, '0.002*"файл" + 0.002*"сервер" + 0.002*"return" + 0.002*"объект" + 0.001*"0" + 0.001*"запрос" + 0.001*"if" + 0.001*"сообщение" + 0.001*"компонент" + 0.001*"устройство"'), (9, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"')]
#
# LDA 25:
# [(11, '0.001*"тимофей" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер" + 0.001*"0" + 0.001*"if" + 0.001*"new" + 0.001*"return" + 0.001*"компонент"'), (20, '0.005*"двигатель" + 0.005*"температура" + 0.004*"прибор" + 0.004*"аккумулятор" + 0.004*"робот" + 0.003*"клетка" + 0.003*"датчик" + 0.003*"усилитель" + 0.003*"печать" + 0.003*"учёный"'), (9, '0.006*"yahoo" + 0.004*"night" + 0.003*"юлмарт" + 0.002*"магнитометр" + 0.002*"verizon" + 0.001*"расследование" + 0.001*"капитализация" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра"'), (0, '0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер" + 0.001*"0" + 0.001*"if" + 0.001*"new" + 0.001*"return" + 0.001*"компонент" + 0.001*"объект"'), (21, '0.004*"младенец" + 0.001*"мгту" + 0.001*"num" + 0.001*"фмрт" + 0.001*"чд" + 0.001*"svchost.exe" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер"'), (18, '0.002*"файл" + 0.001*"сайт" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"услуга" + 0.001*"игра" + 0.001*"объект" + 0.001*"клиент" + 0.001*"сервис"'), (17, '0.002*"rms" + 0.001*"прокси-сервер" + 0.001*"httpd" + 0.001*"gpl" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер" + 0.001*"0" + 0.001*"if"'), (22, '0.001*"captcha" + 0.001*"china" + 0.001*"threshold" + 0.001*"vector3" + 0.001*"new" + 0.001*"антивирусный" + 0.001*"dart" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра"'), (4, '0.004*"лвс" + 0.002*"dusk" + 0.001*"activerecord" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер" + 0.001*"0" + 0.001*"if" + 0.001*"new"'), (16, '0.002*"epam" + 0.002*"pebble" + 0.001*"blackvue" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер" + 0.001*"0" + 0.001*"if" + 0.001*"new"')]
#
# LDA 50:
# [(1, '0.021*"шорткат" + 0.003*"wlan" + 0.003*"svchost.exe" + 0.002*"footer" + 0.002*"м2" + 0.002*"мс-04»" + 0.002*"подросток" + 0.002*"telegraph" + 0.001*"write-host" + 0.001*"angle"'), (11, '0.017*"фсб" + 0.004*"минкомсвязи" + 0.003*"павел" + 0.003*"rust" + 0.002*"спецслужба" + 0.001*"мультивселенная" + 0.001*"des" + 0.001*"firebird" + 0.001*"currently" + 0.001*"фишинга"'), (26, '0.005*"“мы" + 0.003*"деструктор" + 0.003*"blink" + 0.002*"стабилизатор" + 0.002*"esp8266" + 0.002*"dolby" + 0.002*"virtuozzo" + 0.001*"фишер" + 0.001*"atmos" + 0.001*"артём"'), (6, '0.007*"табло" + 0.005*"фбр" + 0.004*"gateway" + 0.004*"itsm" + 0.004*"лидерство" + 0.004*"топ-10" + 0.004*"bittorrent" + 0.004*"сетчатка" + 0.003*"вовлеченность" + 0.003*"doom"'), (17, '0.015*"tarantool" + 0.006*"эссе" + 0.003*"джейсон" + 0.003*"катушка" + 0.002*"комбинированный" + 0.002*"прогон" + 0.002*"lt;script&gt" + 0.002*"lt;/html&gt" + 0.002*"«hello" + 0.001*"битрикс24"'), (49, '0.011*"vds" + 0.003*"широкополосный" + 0.003*"fortran" + 0.002*"упущение" + 0.002*"анб" + 0.002*"пересчитать" + 0.001*"цру" + 0.001*"gopro" + 0.001*"karma" + 0.001*"затвор"'), (10, '0.012*"es" + 0.008*"scrum" + 0.007*"apk" + 0.006*"elasticsearch" + 0.006*"cluster" + 0.005*"middleware" + 0.004*"online" + 0.004*"tftp" + 0.004*"applications" + 0.004*"boot"'), (18, '0.013*"усилитель" + 0.006*"контрольный" + 0.004*"laravel" + 0.004*"client" + 0.004*"искажение" + 0.004*"«вконтакте»" + 0.004*"образовательный" + 0.004*"конденсатор" + 0.003*"redis" + 0.003*"uri"'), (2, '0.014*"systemjs" + 0.006*"meetup" + 0.006*"hdr" + 0.004*"font-size" + 0.003*"actual" + 0.002*"хостовый" + 0.002*"ventures" + 0.002*"canary" + 0.002*"wide" + 0.002*"qemu"'), (47, '0.009*"ведомство" + 0.008*"vk.com" + 0.006*"3cx" + 0.005*"centos" + 0.005*"provider" + 0.004*"unreal" + 0.004*"broadcast" + 0.004*"repeat" + 0.004*"akka" + 0.004*"viewport"')]
#
# LDA 100:
# [(16, '0.012*"rw" + 0.007*"browser" + 0.007*"11:00" + 0.005*"neon" + 0.004*"агрегат" + 0.003*"nvme" + 0.003*"money" + 0.002*"altera" + 0.002*"акт" + 0.002*"vive"'), (15, '0.011*"nodejs" + 0.010*"curl" + 0.005*"reactos" + 0.004*"бп" + 0.004*"c2" + 0.004*"288" + 0.003*"dim" + 0.002*"таск" + 0.002*"s6" + 0.002*"обои"'), (33, '0.026*"флешек" + 0.017*"detail" + 0.010*"регистратор" + 0.010*"ранг" + 0.007*"3м" + 0.007*"салон" + 0.007*"широкополосный" + 0.007*"boot" + 0.005*"zabbix" + 0.004*"клеить"'), (60, '0.025*"корея" + 0.015*"корейский" + 0.012*"м3" + 0.005*"стереть" + 0.005*"кореец" + 0.004*"прибытие" + 0.003*"банкротство" + 0.003*"cas" + 0.003*"bros" + 0.002*"чп"'), (37, '0.008*"тимофей" + 0.008*"видеонаблюдение" + 0.005*"симметрия" + 0.005*"активироваться" + 0.004*"dsl" + 0.004*"temperature" + 0.004*"вадим" + 0.003*"аудиомания" + 0.003*"acceptance" + 0.003*"лого"'), (51, '0.020*"flask" + 0.011*"3d-принтер" + 0.009*"протез" + 0.006*"концепт" + 0.005*"3d-печать" + 0.005*"rtt" + 0.005*"cad" + 0.004*"подросток" + 0.004*"облик" + 0.003*"1968"'), (86, '0.036*"фас" + 0.010*"штраф" + 0.010*"лабораторный" + 0.009*"combine" + 0.008*"repeat" + 0.007*"вердикт" + 0.007*"январь" + 0.006*"темнота" + 0.006*"жалоба" + 0.005*"игорь"'), (96, '0.023*"implicit" + 0.009*"passed" + 0.008*"meta" + 0.007*"vector3" + 0.007*"lt;button" + 0.006*"мошеннический" + 0.005*"1f" + 0.003*"одиночество" + 0.003*"class="btn" + 0.003*"0f"'), (46, '0.009*"рн" + 0.005*"стабилизатор" + 0.003*"тс" + 0.003*"вагон" + 0.002*"blind" + 0.002*"«можный" + 0.002*"epic" + 0.001*"pick" + 0.001*"uml" + 0.001*"списание"'), (94, '0.011*"headhunter" + 0.009*"чд" + 0.006*"цех" + 0.006*"freebsd" + 0.005*"tags" + 0.004*"шт" + 0.003*"cdr" + 0.003*"4.4" + 0.002*"16gb" + 0.002*"страхование"')]

# %% [markdown]
# Темы стали хуже. В LDA 50 и 100 появилось много слов из программного кода и темы вообще неразборчивые.
#
# Пример изменения темы в LDA 10 :
#
# tfidf = False:
#
# (2, '0.014*"сервер" + 0.009*"сеть" + 0.009*"файл" + 0.006*"устройство" + 0.006*"настройка" + 0.005*"доступ" + 0.005*"пакет" + 0.004*"модуль" + 0.004*"запрос" + 0.004*"адрес"')
#
# tfidf = True:
#
# (2, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"сеть" + 0.001*"сайт" + 0.001*"браузер" + 0.001*"игра" + 0.001*"объект" + 0.001*"программа" + 0.001*"метод"')

# %% [markdown]
# Пример изменения темы в LDA 25 :
#
# tfidf = False:
#
# (21, '0.016*"студент" + 0.014*"курс" + 0.009*"программа" + 0.008*"программирование" + 0.007*"участник" + 0.006*"обучение" + 0.006*"программист" + 0.005*"лекция" + 0.005*"знание" + 0.005*"электроника"')
#
# tfidf = True:
#
# (21, '0.004*"младенец" + 0.001*"мгту" + 0.001*"num" + 0.001*"фмрт" + 0.001*"чд" + 0.001*"svchost.exe" + 0.001*"файл" + 0.001*"устройство" + 0.001*"игра" + 0.001*"сервер"')

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
stexts = [' '.join(text) for text in texts]

# %%
def nmf_model(stexts, n_components=10, alpha=0, max_features=25000, min_df=5, max_df=0.3, lowercase=False, ngram_range=(1,2)):
        
    vectorizer = TfidfVectorizer(max_features=max_features,
                                 min_df=min_df,
                                 max_df=max_df,
                                 lowercase=lowercase)
    X = vectorizer.fit_transform(stexts)
    
    nmf_model = NMF(n_components=n_components, random_state=40, alpha=alpha)
    nmf_model.fit(X)
    
    return nmf_model, vectorizer

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(model.n_components):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
nmf_model, vectorizer = nmf_model(stexts)

# %%
get_nmf_topics(nmf_model, 10)
# Out:
#          Topic # 01 Topic # 02 Topic # 03   Topic # 04 Topic # 05  \
# 0             книга     public       игра  космический       файл
# 1            доклад     return      игрок      спутник     сервер
# 2              язык       void    игровой       орбита     запрос
# 3           продукт         if     играть        земля    windows
# 4       программист        new   персонаж    вселенная  настройка
# 5              друг     string      unity         марс   страница
# 6  программирование        var      steam      аппарат     строка
# 7       конференция      класс         vr       ракета     скрипт
# 8              опыт    private     движок      энергия       ключ
# 9        заниматься        int  мобильный      планета      пакет
#
#        Topic # 06 Topic # 07   Topic # 08 Topic # 09    Topic # 10
# 0          клиент         lt   устройство        the          мозг
# 1          услуга         gt       камера         to      обучение
# 2          сервис        div     смартфон         of        учёный
# 3           рынок      react         звук        and            ия
# 4            сеть  компонент       корпус         in  исследование
# 5          бизнес     return      телефон         is      алгоритм
# 6    безопасность      const         цена         on       пациент
# 7  инфраструктура    элемент       датчик        for         метод
# 8            сайт         if  аккумулятор        end        клетка
# 9      технология        int    процессор         if     нейросеть

# %% [markdown]
# ##### Проделайте такие же действия для NMF

# %% [markdown]
# #### NMF 10

# %%
nmf_model, vectorizer = nmf_model(stexts, n_components=10, ngram_range=(1,2))

# %%
print('NMf 10:', get_nmf_topics(nmf_model, 10))
# Out:
# NMf 10:          Topic # 01 Topic # 02 Topic # 03   Topic # 04 Topic # 05  \
# 0             книга     public       игра  космический       файл
# 1            доклад     return      игрок      спутник     сервер
# 2              язык       void    игровой       орбита     запрос
# 3           продукт         if     играть        земля    windows
# 4       программист        new   персонаж    вселенная  настройка
# 5              друг     string      unity         марс   страница
# 6  программирование        var      steam      аппарат     строка
# 7       конференция      класс         vr       ракета     скрипт
# 8              опыт    private     движок      энергия       ключ
# 9        заниматься        int  мобильный      планета      пакет
#
#        Topic # 06 Topic # 07   Topic # 08 Topic # 09    Topic # 10
# 0          клиент         lt   устройство        the          мозг
# 1          услуга         gt       камера         to      обучение
# 2          сервис        div     смартфон         of        учёный
# 3           рынок      react         звук        and            ия
# 4            сеть  компонент       корпус         in  исследование
# 5          бизнес     return      телефон         is      алгоритм
# 6    безопасность      const         цена         on       пациент
# 7  инфраструктура    элемент       датчик        for         метод
# 8            сайт         if  аккумулятор        end        клетка
# 9      технология        int    процессор         if     нейросеть

# %% [markdown]
# #### NMF 25

# %%
nmf_model, vectorizer = nmf_model(stexts, n_components=25, ngram_range=(1,2))

# %%
print('NMf 25:', get_nmf_topics(nmf_model, 10))
# Out:
# NMf 25:     Topic # 01 Topic # 02 Topic # 03   Topic # 04  Topic # 05  Topic # 06  \
# 0      продукт         if       игра  космический      объект       рынок
# 1    сотрудник     return      игрок      спутник    значение       рубль
# 2       клиент       else    игровой       орбита     элемент  российский
# 3       бизнес        end     играть       ракета       метод       товар
# 4         опыт        amp   персонаж         марс       класс      страна
# 5     заказчик        var         vr      аппарат        блок      россия
# 6  программист        int      steam        земля    алгоритм    блокчейн
# 7       деньга   function      unity      станция       точка        цена
# 8     менеджер       true     движок         наса    свойство      деньга
# 9         идея      false   геймплей         луна  переменный     миллион
#
#   Topic # 07   Topic # 08 Topic # 09     Topic # 10     ...      Topic # 16  \
# 0         lt   устройство        the             ия     ...       вселенная
# 1         gt       камера         to       обучение     ...       галактика
# 2        div     смартфон         of      нейросеть     ...         энергия
# 3     return         звук        and          робот     ...          звезда
# 4      const       сигнал         in      интеллект     ...         материя
# 5  компонент      телефон         is           сеть     ...          тёмный
# 6      input       датчик         on  искусственный     ...          солнце
# 7        int  аккумулятор        for       машинный     ...          теория
# 8       html      наушник        you      нейронный     ...            свет
# 9      class      android       from       алгоритм     ...      гравитация
#
#      Topic # 17  Topic # 18     Topic # 19    Topic # 20 Topic # 21  \
# 0          мозг        файл          атака        печать       сайт
# 1        учёный       папка   безопасность       принтер   страница
# 2       пациент      скрипт     уязвимость            3d    реклама
# 3        клетка     windows  злоумышленник        станок     google
# 4  исследование      строка     устройство      материал    контент
# 5   заболевание       пакет         пароль  производство    браузер
# 6       болезнь      сборка         защита       пластик  рекламный
# 7           ген  директория    вредоносный            мм     клиент
# 8          врач       linux         доступ        деталь      домен
# 9      организм      модуль           сеть       изделие     трафик
#
#   Topic # 22        Topic # 23  Topic # 24  Topic # 25
# 0     public              язык         бот      сервер
# 1       void  программирование   сообщение      запрос
# 2        new       программист    telegram        база
# 3     string               php         чат          ip
# 4    private              java       канал      сервис
# 5     return           перевод         api       адрес
# 6      class         программа    телеграм       домен
# 7     static            лекция  мессенджер        ключ
# 8      класс            python      сервис         php
# 9        var       локализация         bot  сертификат
#
# [10 rows x 25 columns]

# %% [markdown]
# #### NMF 50

# %%
nmf_model, vectorizer = nmf_model(stexts, n_components=50, ngram_range=(1,2))

# %%
print('NMf 50:', get_nmf_topics(nmf_model, 10))
# Out:
# NMf 50:     Topic # 01      Topic # 02 Topic # 03   Topic # 04    Topic # 05  \
# 0    сотрудник             var       игра         марс    устройство
# 1       деньга        function    игровой        земля     мобильный
# 2  программист             new     играть  космический         умный
# 3        жизнь          return      steam      аппарат        девайс
# 4         опыт            case      unity      планета        гаджет
# 5       понять             let     движок         луна  беспроводный
# 6       думать           const   nintendo       орбита        датчик
# 7         идея  xmlhttprequest       жанр      станция    управление
# 8          кто             url         vr         наса           iot
# 9       знание            true  приставка     астероид           дом
#
#    Topic # 06 Topic # 07   Topic # 08 Topic # 09     Topic # 10     ...       \
# 0       рубль         lt     смартфон        the             ия     ...
# 1  российский         gt      телефон         to       обучение     ...
# 2         000        div        экран         of      нейросеть     ...
# 3      россия     return       xiaomi        and      интеллект     ...
# 4       рынок      const  аккумулятор         in  искусственный     ...
# 5       доход  компонент      дисплей         is       машинный     ...
# 6      страна      input        apple        for      нейронный     ...
# 7       налог         li      ноутбук         on    изображение     ...
# 8       закон       html           mi        you       алгоритм     ...
# 9         ооо        std           гб       this       deepmind     ...
#
#   Topic # 41  Topic # 42        Topic # 43   Topic # 44 Topic # 45 Topic # 46  \
# 0     сигнал        сайт            лекция        плата     клиент        php
# 1    частота    страница              курс   напряжение        crm    symfony
# 2    антенна     реклама           студент          ток        3cx    laravel
# 3      канал     браузер       университет      питание     письмо        yii
# 4   диапазон     контент  программирование       датчик     услуга     docker
# 5      связь   рекламный         профессор  температура     бизнес   прислать
# 6     фильтр       домен             видео       корпус    продажа      релиз
# 7    станция  посетитель             школа   контроллер     звонок        api
# 8  искажение       текст         поведение        схема         тз     массив
# 9   значение      ссылка         знакомить        лампа  сотрудник      nginx
#
#   Topic # 47  Topic # 48   Topic # 49   Topic # 50
# 0      игрок      import       ракета   автомобиль
# 1       игра         def      спутник  беспилотный
# 2    игровой         val    двигатель       машина
# 3       враг        from      ступень        tesla
# 4     миссия      return       spacex     водитель
# 5   персонаж         new       орбита    автопилот
# 6    комната        case  космический       дорога
# 7   движение      python         пуск         uber
# 8     играть      string     носитель          ibm
# 9       лига  библиотека      корабль       watson
#
# [10 rows x 50 columns]

# %% [markdown]
# #### NMF 100

# %%
nmf_model, vectorizer = nmf_model(stexts, n_components=100, ngram_range=(1,2))

# %%
print('NMf 100:', get_nmf_topics(nmf_model, 10))
# Out:
# NMf 100:   Topic # 01 Topic # 02 Topic # 03 Topic # 04    Topic # 05       Topic # 06  \
# 0     деньга       true       игра     звезда    устройство       российский
# 1      жизнь      false    игровой  галактика         умный            закон
# 2     думать       func     играть   телескоп        девайс           россия
# 3     понять       line      steam     солнце     мобильный           страна
# 4     вообще       file      unity    планета        гаджет            рынок
# 5   понимать       name     движок       небо        датчик               рф
# 6       опыт       type   nintendo     светов  беспроводный         документ
# 7        кто       null       жанр  солнечный    управление              сша
# 8      ничто     string  приставка       свет          шлюз  государственный
# 9       идея         ok   геймплей      земля           iot            китай
#
#   Topic # 07   Topic # 08 Topic # 09   Topic # 10      ...         Topic # 90  \
# 0         lt     смартфон        the     обучение      ...              tesla
# 1         gt      телефон         to     алгоритм      ...            батарея
# 2        div       xiaomi         of       модель      ...             motors
# 3      input        экран        and    нейросеть      ...        аккумулятор
# 4       html  аккумулятор         in     машинный      ...          panasonic
# 5         li        apple         is    нейронный      ...               маск
# 6        std      дисплей        for  изображение      ...       производство
# 7       body           mi         on         сеть      ...              model
# 8      class           гб        you      признак      ...              илона
# 9       type       iphone         my         слой      ...             стекло
#
#     Topic # 91   Topic # 92    Topic # 93     Topic # 94  Topic # 95  \
# 0    сообщение     blackvue        станок          лампа        сеть
# 1       сервис  регистратор  производство           свет      трафик
# 2        канал       модель           чпу            cri       связь
# 3         байт          gps            мм             лм    оператор
# 4     отправка        видео       изделие      освещение    интернет
# 5   отправлять    китайский      шпиндель         индекс      доступ
# 6      message       запись        деталь  цветопередача       канал
# 7      событие        рубль       рабочий       лампочка  социальный
# 8  уведомление      глонасс  изготовление   светодиодный     сетевой
# 9      очередь        бренд      материал      пульсация     станция
#
#     Topic # 96   Topic # 97   Topic # 98    Topic # 99
# 0       pebble       docker       модуль     jetbrains
# 1       fitbit          amp        пакет         night
# 2         часы    контейнер       плагин         видео
# 3       сделка         sudo          api  рассказывать
# 4      миллион         echo          npm      обсудить
# 5        умный      install           js   публиковать
# 6  kickstarter          run  репозиторий        kotlin
# 7        apple          apt  зависимость       слушать
# 8      продажа        nginx    фреймворк        удобно
# 9   сообщество  репозиторий       сборка   комментарий
#
# [10 rows x 100 columns]

# %% [markdown]
# ##### В отдельной ячейке напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA

# %% [markdown]
# NMF в сравнении с LDA работает лучше, темы сформированы отлично. Однако, при 50 и 100 топиках снова появляется много мусора.
# Самые хорошие получившиеся темы:
# NMf 25:
#
# Topic # 04
#
# космический
# спутник
# орбита
# ракета
# марс
# аппарат
# земля
# станция
# наса
# луна
#
# Topic # 17
#
# мозг
# учёный
# пациент
# клетка
# исследование
# заболевание
# болезнь
# ген
# врач
# организм
